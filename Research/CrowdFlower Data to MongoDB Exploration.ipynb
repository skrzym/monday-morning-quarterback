# %%
import pandas as pd
import numpy as np
import re

# %%
cdata_all = pd.read_csv("Data/Football-Scenarios-DFE-832307.csv")

# %%
cdata = cdata_all[cdata_all['_golden']==False]

# %% [markdown]
#  **down | yards to 1st down | field position | quarter | time left on the clock | score differential**

# %%
def convert_ordinal(value):
    if value == 'first':
        return 1
    elif value == 'second':
        return 2
    elif value == 'third':
        return 3
    elif value == 'fourth':
        return 4
    else:
        return value

# %%
def convert_clock(value):
    min = re.search('(.+?) minute', value)
    sec = re.search('(.+?) second', value)
    if min:
        return int(min.group(1)) * 60
    elif sec:
        return int(sec.group(1))
    else:
        return value

# %%
def convert_scoredelta(value):
    down_by = re.search('down by (.+?)', value)
    up_by = re.search('up by (.+?)', value)
    
    if down_by:
        return int(down_by.group(1)) * -1
    elif up_by:
        return int(up_by.group(1))
    else:
        return value

# %%
def convert_fieldpos(value):
    _list = value.split(' ')
    if len(_list) > 1:
        return int(_list[1])
    elif len(_list) == 1:
        return 100 - int(_list[0])
    else:
        return value

# %%
def extract(line):
    down = re.search('It is (.+?) down', line)
    ytg = re.search('down and (.+?). ',line)
    fieldpos = re.search("your (.+?) yardline", line)
    quarter = re.search('the (.+?) quarter', line)
    clock = re.search('There is (.+?) left', line)
    scoredelta = re.search('You are (.+?) points',line)
    
    extraction = (
        line,
        convert_ordinal(down.group(1)) if down else np.NaN,
        int(ytg.group(1).replace('inches','0')) if ytg else np.NaN,
        convert_fieldpos(fieldpos.group(1)) if fieldpos else np.NaN,
        convert_ordinal(quarter.group(1)) if quarter else np.NaN,
        convert_clock(clock.group(1)) if clock else np.NaN,
        convert_scoredelta(scoredelta.group(1)) if scoredelta else np.NaN
    )
    return extraction

# %%
data = [
    extract(scenario)
    for scenario in cdata.orig_antecedent
]

# %%
df = pd.DataFrame.from_records(data, columns=['scenario','down','ytg','fieldpos','quarter','clock','scoredelta'])
# Out:
#                                                scenario  down   ytg  fieldpos  \
# 0     It is first down and 10. The ball is on your o...   1.0  10.0      20.0
# 1     It is second down and inches. The ball is on y...   2.0   0.0       5.0
# 2     It is second down and inches. The ball is on y...   2.0   0.0      20.0
# 3     It is second down and inches. The ball is on y...   2.0   0.0       5.0
# 4     It is second down and inches. The ball is on y...   2.0   0.0      20.0
# 5     It is second down and inches. The ball is on y...   2.0   0.0      55.0
# 6     It is second down and inches. The ball is on y...   2.0   0.0      80.0
# 7     It is second down and 3. The ball is on your o...   2.0   3.0       5.0
# 8     It is second down and 3. The ball is on your o...   2.0   3.0      20.0
# 9     It is second down and 3. The ball is on your o...   2.0   3.0      20.0
# 10    It is second down and 3. The ball is on your o...   2.0   3.0      20.0
# 11    It is second down and 8. The ball is on your o...   2.0   8.0      20.0
# 12    It is second down and 8. The ball is on your 4...   2.0   8.0      55.0
# 13    It is third down and inches. The ball is on yo...   3.0   0.0      40.0
# 14    It is third down and inches. The ball is on yo...   3.0   0.0      55.0
# 15    It is third down and inches. The ball is on yo...   3.0   0.0      40.0
# 16    It is third down and inches. The ball is on yo...   3.0   0.0      55.0
# 17    It is fourth down and inches. The ball is on y...   4.0   0.0      20.0
# 18                  It is first down and 10. Would you:   1.0  10.0       NaN
# 19                 You are down by 3 points. Would you:   NaN   NaN       NaN
# 20    It is first down and 10. The ball is on your o...   1.0  10.0      20.0
# 21    It is first down and 10. The ball is on your o...   1.0  10.0      40.0
# 22    It is first down and 10. The ball is on your 4...   1.0  10.0      55.0
# 23    It is first down and 10. The ball is on your 2...   1.0  10.0      80.0
# 24    It is first down and 10. The ball is on your o...   1.0  10.0      40.0
# 25    It is first down and 10. The ball is on your 4...   1.0  10.0      55.0
# 26    It is first down and 10. The ball is on your 2...   1.0  10.0      80.0
# 27    It is first down and 10. The ball is on your o...   1.0  10.0      20.0
# 28    It is first down and 10. The ball is on your o...   1.0  10.0      40.0
# 29    It is first down and 10. The ball is on your 4...   1.0  10.0      55.0
# ...                                                 ...   ...   ...       ...
# 3676  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3677  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3678  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3679  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3680  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3681  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3682  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3683  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3684  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3685  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3686  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3687  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3688  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3689  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3690  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3691  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3692  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3693  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3694  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3695  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3696  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3697  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3698  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3699  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3700  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3701  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3702  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3703  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3704  It is second down and inches. The ball is on y...   2.0   0.0      80.0
# 3705  It is second down and 3. The ball is on your 2...   2.0   3.0      80.0
#
#       quarter  clock  scoredelta
# 0         2.0    3.0        -3.0
# 1         2.0    3.0        -3.0
# 2         2.0    3.0        -3.0
# 3         4.0    3.0        -3.0
# 4         4.0    3.0        -3.0
# 5         4.0    3.0        -7.0
# 6         4.0    3.0        -7.0
# 7         4.0    3.0        -3.0
# 8         4.0    3.0        -3.0
# 9         2.0    3.0        -7.0
# 10        4.0    3.0        -7.0
# 11        4.0    3.0        -3.0
# 12        4.0    3.0        -7.0
# 13        4.0    3.0         3.0
# 14        4.0    3.0         3.0
# 15        4.0    3.0         7.0
# 16        4.0    3.0         7.0
# 17        2.0    3.0        -3.0
# 18        NaN    NaN         NaN
# 19        NaN    NaN        -3.0
# 20        1.0    NaN        -3.0
# 21        1.0    NaN        -3.0
# 22        1.0    NaN        -3.0
# 23        1.0    NaN        -3.0
# 24        2.0    3.0        -3.0
# 25        2.0    3.0        -3.0
# 26        2.0    3.0        -3.0
# 27        2.0  120.0        -3.0
# 28        2.0  120.0        -3.0
# 29        2.0  120.0        -3.0
# ...       ...    ...         ...
# 3676      3.0    NaN         NaN
# 3677      4.0    NaN         NaN
# 3678      NaN    NaN        -3.0
# 3679      NaN    NaN        -7.0
# 3680      NaN    NaN        -1.0
# 3681      NaN    NaN        -2.0
# 3682      NaN    NaN         3.0
# 3683      NaN    NaN         7.0
# 3684      NaN    NaN         NaN
# 3685      2.0    NaN         NaN
# 3686      3.0    NaN         NaN
# 3687      4.0    NaN         NaN
# 3688      NaN    NaN        -3.0
# 3689      NaN    NaN        -7.0
# 3690      NaN    NaN        -1.0
# 3691      NaN    NaN        -2.0
# 3692      NaN    NaN         3.0
# 3693      NaN    NaN         7.0
# 3694      NaN    NaN         NaN
# 3695      2.0    NaN         NaN
# 3696      3.0    NaN         NaN
# 3697      4.0    NaN         NaN
# 3698      NaN    NaN        -3.0
# 3699      NaN    NaN        -7.0
# 3700      NaN    NaN        -1.0
# 3701      NaN    NaN        -2.0
# 3702      NaN    NaN         3.0
# 3703      NaN    NaN         7.0
# 3704      2.0    3.0         3.0
# 3705      2.0    3.0        -3.0
#
# [3706 rows x 7 columns]

# %%
df.loc[:,'guess'] = cdata.loc[:,'antecedent']

# %%
df
# Out:
#                                                scenario  down   ytg  fieldpos  \
# 0     It is first down and 10. The ball is on your o...   1.0  10.0      20.0
# 1     It is second down and inches. The ball is on y...   2.0   0.0       5.0
# 2     It is second down and inches. The ball is on y...   2.0   0.0      20.0
# 3     It is second down and inches. The ball is on y...   2.0   0.0       5.0
# 4     It is second down and inches. The ball is on y...   2.0   0.0      20.0
# 5     It is second down and inches. The ball is on y...   2.0   0.0      55.0
# 6     It is second down and inches. The ball is on y...   2.0   0.0      80.0
# 7     It is second down and 3. The ball is on your o...   2.0   3.0       5.0
# 8     It is second down and 3. The ball is on your o...   2.0   3.0      20.0
# 9     It is second down and 3. The ball is on your o...   2.0   3.0      20.0
# 10    It is second down and 3. The ball is on your o...   2.0   3.0      20.0
# 11    It is second down and 8. The ball is on your o...   2.0   8.0      20.0
# 12    It is second down and 8. The ball is on your 4...   2.0   8.0      55.0
# 13    It is third down and inches. The ball is on yo...   3.0   0.0      40.0
# 14    It is third down and inches. The ball is on yo...   3.0   0.0      55.0
# 15    It is third down and inches. The ball is on yo...   3.0   0.0      40.0
# 16    It is third down and inches. The ball is on yo...   3.0   0.0      55.0
# 17    It is fourth down and inches. The ball is on y...   4.0   0.0      20.0
# 18                  It is first down and 10. Would you:   1.0  10.0       NaN
# 19                 You are down by 3 points. Would you:   NaN   NaN       NaN
# 20    It is first down and 10. The ball is on your o...   1.0  10.0      20.0
# 21    It is first down and 10. The ball is on your o...   1.0  10.0      40.0
# 22    It is first down and 10. The ball is on your 4...   1.0  10.0      55.0
# 23    It is first down and 10. The ball is on your 2...   1.0  10.0      80.0
# 24    It is first down and 10. The ball is on your o...   1.0  10.0      40.0
# 25    It is first down and 10. The ball is on your 4...   1.0  10.0      55.0
# 26    It is first down and 10. The ball is on your 2...   1.0  10.0      80.0
# 27    It is first down and 10. The ball is on your o...   1.0  10.0      20.0
# 28    It is first down and 10. The ball is on your o...   1.0  10.0      40.0
# 29    It is first down and 10. The ball is on your 4...   1.0  10.0      55.0
# ...                                                 ...   ...   ...       ...
# 3676  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3677  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3678  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3679  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3680  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3681  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3682  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3683  It is fourth down and 10. The ball is on your ...   4.0  10.0      40.0
# 3684  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3685  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3686  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3687  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3688  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3689  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3690  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3691  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3692  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3693  It is fourth down and 10. The ball is on your ...   4.0  10.0      55.0
# 3694  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3695  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3696  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3697  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3698  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3699  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3700  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3701  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3702  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3703  It is fourth down and 10. The ball is on your ...   4.0  10.0      80.0
# 3704  It is second down and inches. The ball is on y...   2.0   0.0      80.0
# 3705  It is second down and 3. The ball is on your 2...   2.0   3.0      80.0
#
#       quarter  clock  scoredelta                    guess
# 0         2.0    3.0        -3.0        kick a field goal
# 1         2.0    3.0        -3.0        kick a field goal
# 2         2.0    3.0        -3.0        kick a field goal
# 3         4.0    3.0        -3.0        kick a field goal
# 4         4.0    3.0        -3.0        kick a field goal
# 5         4.0    3.0        -7.0                     pass
# 6         4.0    3.0        -7.0                     pass
# 7         4.0    3.0        -3.0        kick a field goal
# 8         4.0    3.0        -3.0        kick a field goal
# 9         2.0    3.0        -7.0                     pass
# 10        4.0    3.0        -7.0                     pass
# 11        4.0    3.0        -3.0        kick a field goal
# 12        4.0    3.0        -7.0                     pass
# 13        4.0    3.0         3.0               kneel down
# 14        4.0    3.0         3.0               kneel down
# 15        4.0    3.0         7.0               kneel down
# 16        4.0    3.0         7.0               kneel down
# 17        2.0    3.0        -3.0        kick a field goal
# 18        NaN    NaN         NaN                      run
# 19        NaN    NaN        -3.0  Don't know / it depends
# 20        1.0    NaN        -3.0                     pass
# 21        1.0    NaN        -3.0                     pass
# 22        1.0    NaN        -3.0                     pass
# 23        1.0    NaN        -3.0                     pass
# 24        2.0    3.0        -3.0        kick a field goal
# 25        2.0    3.0        -3.0                     pass
# 26        2.0    3.0        -3.0                     pass
# 27        2.0  120.0        -3.0                      run
# 28        2.0  120.0        -3.0  Don't know / it depends
# 29        2.0  120.0        -3.0                     pass
# ...       ...    ...         ...                      ...
# 3676      3.0    NaN         NaN                     punt
# 3677      4.0    NaN         NaN        kick a field goal
# 3678      NaN    NaN        -3.0        kick a field goal
# 3679      NaN    NaN        -7.0        kick a field goal
# 3680      NaN    NaN        -1.0                     punt
# 3681      NaN    NaN        -2.0        kick a field goal
# 3682      NaN    NaN         3.0                     punt
# 3683      NaN    NaN         7.0                     punt
# 3684      NaN    NaN         NaN                     punt
# 3685      2.0    NaN         NaN                     punt
# 3686      3.0    NaN         NaN                     punt
# 3687      4.0    NaN         NaN                     punt
# 3688      NaN    NaN        -3.0                     punt
# 3689      NaN    NaN        -7.0                     punt
# 3690      NaN    NaN        -1.0  Don't know / it depends
# 3691      NaN    NaN        -2.0                     punt
# 3692      NaN    NaN         3.0                     punt
# 3693      NaN    NaN         7.0                     punt
# 3694      NaN    NaN         NaN                     punt
# 3695      2.0    NaN         NaN                     punt
# 3696      3.0    NaN         NaN                     punt
# 3697      4.0    NaN         NaN                     punt
# 3698      NaN    NaN        -3.0                     punt
# 3699      NaN    NaN        -7.0                     punt
# 3700      NaN    NaN        -1.0                     punt
# 3701      NaN    NaN        -2.0                     punt
# 3702      NaN    NaN         3.0                     punt
# 3703      NaN    NaN         7.0                     punt
# 3704      2.0    3.0         3.0                     pass
# 3705      2.0    3.0        -3.0               kneel down
#
# [3706 rows x 8 columns]
