# %%
# %matplotlib inline

# %%
import report as r

# %%
r.figure_1

# %%
r.figure_2

# %%
r.figure_3

# %%
r.figure_4

# %%
r.figure_5

# %%
r.figure_6

# %%
r.figure_7

# %%
r.figure_8

# %%
r.figure_9

# %%
r.figure_10

# %%
r.figure_11
