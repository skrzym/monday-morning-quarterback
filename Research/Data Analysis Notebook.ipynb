# %%
import pandas as pd
import numpy as np
import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-47-d34761b0aed8> in <module>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import nflgame
#
# ImportError: No module named 'nflgame'

# %%
cdata = pd.read_csv("Football-Scenarios-DFE-832307.csv")

# %%
cdata
# Out:
#        _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     831005673   False   finalized                   5    11/20/15 20:20
# 1     831005674   False   finalized                   5    11/18/15 21:59
# 2     831005675   False   finalized                   5    11/20/15 22:43
# 3     831005676   False   finalized                   5     11/19/15 7:41
# 4     831005677   False   finalized                   5     11/21/15 8:01
# 5     831005678   False   finalized                   5    11/21/15 18:25
# 6     831005679   False   finalized                   5    11/20/15 20:31
# 7     831005680   False   finalized                   5    11/20/15 19:10
# 8     831005681   False   finalized                   5    11/20/15 18:20
# 9     831005682   False   finalized                   5     11/20/15 9:58
# 10    831005683   False   finalized                   5    11/20/15 15:49
# 11    831005684   False   finalized                   5    11/19/15 15:23
# ...

# %%
set(cdata.option1)
# Out:
# {' punt'}

# %%
set(cdata.option2)
# Out:
# {' kick a field goal'}

# %%
set(cdata.option3)
# Out:
# {' run'}

# %%
set(cdata.option4)
# Out:
# {' pass'}

# %%
set(cdata.option5)
# Out:
# {' kneel down'}

# %%
len(cdata)
# Out:
# 3730

# %%
cdata.orig_antecedent.value_counts()
# Out:
#  You are up by 7 points. Would you:                                                                                                                              13
#  You are down by 10 points. Would you:                                                                                                                           13
#  You are down by 3 points. Would you:                                                                                                                            13
#  You are up by 3 points. Would you:                                                                                                                              13
#  You are down by 7 points. Would you:                                                                                                                            13
#  You are down by 20 points. Would you:                                                                                                                           13
# ...

# %%
cdata[cdata.orig_antecedent.apply(lambda x: len(x))==158].orig_antecedent.iloc[0]
# Out:
# "It is second down and inches. The ball is on your opponent's 20 yardline. There is 3 seconds left in the second quarter. You are down by 10 points. Would you:"

# %%
cdata.orig_antecedent.str.split('.')[1]
# Out:
# ['It is second down and inches',
#  " The ball is on your opponent's 5 yardline",
#  ' There is 3 seconds left in the second quarter',
#  ' You are down by 3 points',
#  ' Would you:']

# %%
cdata['down'] = np.nan
cdata['position'] = np.nan
cdata['clock'] = np.nan
cdata['quarter'] = np.nan
cdata['score_diff'] = np.nan

# %%
cdata
# Out:
#        _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     831005673   False   finalized                   5    11/20/15 20:20
# 1     831005674   False   finalized                   5    11/18/15 21:59
# 2     831005675   False   finalized                   5    11/20/15 22:43
# 3     831005676   False   finalized                   5     11/19/15 7:41
# 4     831005677   False   finalized                   5     11/21/15 8:01
# 5     831005678   False   finalized                   5    11/21/15 18:25
# 6     831005679   False   finalized                   5    11/20/15 20:31
# 7     831005680   False   finalized                   5    11/20/15 19:10
# 8     831005681   False   finalized                   5    11/20/15 18:20
# 9     831005682   False   finalized                   5     11/20/15 9:58
# 10    831005683   False   finalized                   5    11/20/15 15:49
# 11    831005684   False   finalized                   5    11/19/15 15:23
# ...

# %%
cdata[cdata.orig_antecedent==cdata.iloc[1].orig_antecedent]
# Out:
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 1  831005674   False   finalized                   5    11/18/15 21:59
#
#           antecedent  antecedent:confidence  \
# 1  kick a field goal                    1.0
#
#                                      orig_antecedent antecedent_gold option1  \
# 1  It is second down and inches. The ball is on y...             NaN    punt
#
#               option2 option3 option4      option5  down  position  clock  \
# 1   kick a field goal     run    pass   kneel down   NaN       NaN    NaN
#
#    score_diff  quarter
# 1         NaN      NaN
